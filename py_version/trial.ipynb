# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = np.load('data/rand_segment_x_data_set.npy')
plt.figure(figsize=(10,8))
x = np.linspace(0,100,100)
y = dataset[:,9]
plt.plot(x,y)
plt.grid()
plt.show()
